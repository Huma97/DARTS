# %%
# %load_ext autoreload
# %autoreload 2
from __future__ import print_function
import os, cPickle
from collections import defaultdict, OrderedDict

import numpy as np
import keras.backend as K

import kde
import simplebinmi

import utils
trn, tst = utils.get_mnist()

# Which measure to plot
infoplane_measure = 'upper'
#infoplane_measure = 'bin'

DO_SAVE        = False    # Whether to save plots or just show them
DO_LOWER       = True    # (infoplane_measure == 'lower')   # Whether to compute lower bounds also
DO_BINNED      = True    #(infoplane_measure == 'bin')     # Whether to compute MI estimates based on binning

MAX_EPOCHS = 1000      # Max number of epoch for which to compute mutual information measure
# MAX_EPOCHS = 1000
COLORBAR_MAX_EPOCHS = 1000

# Directories from which to load saved layer activity
ARCH = '1024-20-20-20'
#ARCH = '20-20-20-20-20-20'
#ARCH = '32-28-24-20-16-12'
#ARCH = '32-28-24-20-16-12-8-8'
DIR_TEMPLATE = '%%s_%s'%ARCH

# Functions to return upper and lower bounds on entropy of layer activity
noise_variance = 1e-1                    # Added Gaussian noise variance
Klayer_activity = K.placeholder(ndim=2)  # Keras placeholder 
entropy_func_upper = K.function([Klayer_activity,], [kde.entropy_estimator_kl(Klayer_activity, noise_variance),])
entropy_func_lower = K.function([Klayer_activity,], [kde.entropy_estimator_bd(Klayer_activity, noise_variance),])


# nats to bits conversion factor
nats2bits = 1.0/np.log(2) 


# Save indexes of tests data for each of the output classes
saved_labelixs = {}
for i in range(10):
    saved_labelixs[i] = tst.y == i

labelprobs = np.mean(tst.Y, axis=0)
# Out:
# Using TensorFlow backend.

# %%
PLOT_LAYERS    = None     # Which layers to plot.  If None, all saved layers are plotted 

# Data structure used to store results
measures = OrderedDict()
measures['relu'] = {}
measures['tanh'] = {}

# %% [markdown]
# Compute MI measures
# -----

# %%
for activation in measures.keys():
    cur_dir = 'rawdata/' + DIR_TEMPLATE % activation
    if not os.path.exists(cur_dir):
        print("Directory %s not found" % cur_dir)
        continue
        
    # Load files saved during each epoch, and compute MI measures of the activity in that epoch
    print('*** Doing %s ***' % cur_dir)
    for epochfile in sorted(os.listdir(cur_dir)):
        if not epochfile.startswith('epoch'):
            continue
            
        fname = cur_dir + "/" + epochfile
        with open(fname, 'rb') as f:
            d = cPickle.load(f)

        epoch = d['epoch']
        if epoch in measures[activation]: # Skip this epoch if its already been processed
            continue                      # this is a trick to allow us to rerun this cell multiple times)
            
        if epoch > MAX_EPOCHS:
            continue

        print("Doing", fname)
        
        num_layers = len(d['data']['activity_tst'])

        if PLOT_LAYERS is None:
            PLOT_LAYERS = []
            for lndx in range(num_layers):
                #if d['data']['activity_tst'][lndx].shape[1] < 200 and lndx != num_layers - 1:
                PLOT_LAYERS.append(lndx)
                
        cepochdata = defaultdict(list)
        for lndx in range(num_layers):
            activity = d['data']['activity_tst'][lndx]

            # Compute marginal entropies
            h_upper = entropy_func_upper([activity,])[0]
            if DO_LOWER:
                h_lower = entropy_func_lower([activity,])[0]
                
            # Layer activity given input. This is simply the entropy of the Gaussian noise
            hM_given_X = kde.kde_condentropy(activity, noise_variance)

            # Compute conditional entropies of layer activity given output
            hM_given_Y_upper=0.
            for i in range(10):
                hcond_upper = entropy_func_upper([activity[saved_labelixs[i],:],])[0]
                hM_given_Y_upper += labelprobs[i] * hcond_upper
                
            if DO_LOWER:
                hM_given_Y_lower=0.
                for i in range(10):
                    hcond_lower = entropy_func_lower([activity[saved_labelixs[i],:],])[0]
                    hM_given_Y_lower += labelprobs[i] * hcond_lower
                    
                    
            # # It's also possible to treat the last layer probabilistically. Here is the 
            # # code to do so. Should only be applied when lndx == num_layers - 1

            # ps = activity.mean(axis=0)
            # h_lower = h_upper = sum([-p*np.log(p) for p in ps if p != 0])

            # x = -activity * np.log(activity)
            # x[activity == 0] = 0.
            # hM_given_X = np.mean(x.sum(axis=1))

            # hM_given_Y=0.
            # for i in range(10):
            #     ixs = tst.y[::subsample] == i
            #     ps = activity[ixs,:].mean(axis=0)
            #     hcond = sum([-p*np.log(p) for p in ps if p != 0])
            #     prob = np.mean(ixs)
            #     hM_given_Y += l * hcond
            # hM_given_Y_lower = hM_given_Y_upper = hM_given_Y
            # del hM_given_Y
                
            cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
            cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
            cepochdata['H_M_upper'  ].append( nats2bits * h_upper )

            pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1])
            if DO_LOWER:  # Compute lower bounds
                cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

            if DO_BINNED: # Compute binner estimates
                binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, 0.5)
                cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                cepochdata['MI_YM_bin'].append( nats2bits * binym )
                pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])
            
            print('- Layer %d %s' % (lndx, pstr) )

        measures[activation][epoch] = cepochdata
# Out:
# Directory rawdata/relu_1024-20-20-20 not found
# *** Doing rawdata/tanh_1024-20-20-20 ***
# Doing rawdata/tanh_1024-20-20-20/epoch00000000
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.612, MI(Y;M)=3.066 | lower: MI(X;M)=5.620, MI(Y;M)=1.778 | bin: MI(X;M)=13.177, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=9.938, MI(Y;M)=2.594 | lower: MI(X;M)=4.746, MI(Y;M)=1.623 | bin: MI(X;M)=13.066, MI(Y;M)=3.297
# - Layer 3 upper: MI(X;M)=8.627, MI(Y;M)=2.321 | lower: MI(X;M)=4.205, MI(Y;M)=1.547 | bin: MI(X;M)=12.771, MI(Y;M)=3.232
# - Layer 4 upper: MI(X;M)=0.313, MI(Y;M)=0.190 | lower: MI(X;M)=0.081, MI(Y;M)=0.050 | bin: MI(X;M)=-0.000, MI(Y;M)=-0.000
# Doing rawdata/tanh_1024-20-20-20/epoch00000001
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.829, MI(Y;M)=3.185 | lower: MI(X;M)=6.348, MI(Y;M)=2.186 | bin: MI(X;M)=13.165, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.351, MI(Y;M)=2.892 | lower: MI(X;M)=5.413, MI(Y;M)=2.048 | bin: MI(X;M)=12.992, MI(Y;M)=3.306
# - Layer 3 upper: MI(X;M)=9.120, MI(Y;M)=2.668 | lower: MI(X;M)=4.882, MI(Y;M)=1.974 | bin: MI(X;M)=12.764, MI(Y;M)=3.274
# - Layer 4 upper: MI(X;M)=0.590, MI(Y;M)=0.399 | lower: MI(X;M)=0.157, MI(Y;M)=0.108 | bin: MI(X;M)=-0.000, MI(Y;M)=-0.000
# Doing rawdata/tanh_1024-20-20-20/epoch00000002
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.905, MI(Y;M)=3.228 | lower: MI(X;M)=6.741, MI(Y;M)=2.378 | bin: MI(X;M)=13.159, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.471, MI(Y;M)=3.009 | lower: MI(X;M)=5.740, MI(Y;M)=2.250 | bin: MI(X;M)=12.958, MI(Y;M)=3.314
# - Layer 3 upper: MI(X;M)=9.341, MI(Y;M)=2.824 | lower: MI(X;M)=5.245, MI(Y;M)=2.190 | bin: MI(X;M)=12.694, MI(Y;M)=3.292
# - Layer 4 upper: MI(X;M)=0.872, MI(Y;M)=0.617 | lower: MI(X;M)=0.239, MI(Y;M)=0.172 | bin: MI(X;M)=0.213, MI(Y;M)=0.093
# Doing rawdata/tanh_1024-20-20-20/epoch00000003
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.940, MI(Y;M)=3.250 | lower: MI(X;M)=7.003, MI(Y;M)=2.497 | bin: MI(X;M)=13.160, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.526, MI(Y;M)=3.074 | lower: MI(X;M)=5.951, MI(Y;M)=2.372 | bin: MI(X;M)=12.911, MI(Y;M)=3.311
# - Layer 3 upper: MI(X;M)=9.483, MI(Y;M)=2.918 | lower: MI(X;M)=5.490, MI(Y;M)=2.323 | bin: MI(X;M)=12.652, MI(Y;M)=3.299
# - Layer 4 upper: MI(X;M)=1.146, MI(Y;M)=0.831 | lower: MI(X;M)=0.323, MI(Y;M)=0.240 | bin: MI(X;M)=0.664, MI(Y;M)=0.420
# Doing rawdata/tanh_1024-20-20-20/epoch00000004
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.961, MI(Y;M)=3.264 | lower: MI(X;M)=7.196, MI(Y;M)=2.582 | bin: MI(X;M)=13.174, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.560, MI(Y;M)=3.115 | lower: MI(X;M)=6.103, MI(Y;M)=2.458 | bin: MI(X;M)=12.874, MI(Y;M)=3.312
# - Layer 3 upper: MI(X;M)=9.582, MI(Y;M)=2.981 | lower: MI(X;M)=5.667, MI(Y;M)=2.414 | bin: MI(X;M)=12.620, MI(Y;M)=3.303
# - Layer 4 upper: MI(X;M)=1.394, MI(Y;M)=1.026 | lower: MI(X;M)=0.404, MI(Y;M)=0.305 | bin: MI(X;M)=1.029, MI(Y;M)=0.683
# Doing rawdata/tanh_1024-20-20-20/epoch00000005
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.978, MI(Y;M)=3.273 | lower: MI(X;M)=7.350, MI(Y;M)=2.648 | bin: MI(X;M)=13.165, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.595, MI(Y;M)=3.144 | lower: MI(X;M)=6.231, MI(Y;M)=2.526 | bin: MI(X;M)=12.848, MI(Y;M)=3.313
# - Layer 3 upper: MI(X;M)=9.666, MI(Y;M)=3.028 | lower: MI(X;M)=5.813, MI(Y;M)=2.484 | bin: MI(X;M)=12.583, MI(Y;M)=3.301
# - Layer 4 upper: MI(X;M)=1.622, MI(Y;M)=1.206 | lower: MI(X;M)=0.481, MI(Y;M)=0.368 | bin: MI(X;M)=1.319, MI(Y;M)=0.897
# Doing rawdata/tanh_1024-20-20-20/epoch00000006
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=11.998, MI(Y;M)=3.280 | lower: MI(X;M)=7.483, MI(Y;M)=2.703 | bin: MI(X;M)=13.156, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.635, MI(Y;M)=3.167 | lower: MI(X;M)=6.345, MI(Y;M)=2.583 | bin: MI(X;M)=12.833, MI(Y;M)=3.313
# - Layer 3 upper: MI(X;M)=9.743, MI(Y;M)=3.066 | lower: MI(X;M)=5.940, MI(Y;M)=2.543 | bin: MI(X;M)=12.562, MI(Y;M)=3.301
# - Layer 4 upper: MI(X;M)=1.835, MI(Y;M)=1.373 | lower: MI(X;M)=0.558, MI(Y;M)=0.431 | bin: MI(X;M)=1.629, MI(Y;M)=1.112
# Doing rawdata/tanh_1024-20-20-20/epoch00000007
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.016, MI(Y;M)=3.286 | lower: MI(X;M)=7.594, MI(Y;M)=2.747 | bin: MI(X;M)=13.146, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=10.671, MI(Y;M)=3.185 | lower: MI(X;M)=6.442, MI(Y;M)=2.630 | bin: MI(X;M)=12.821, MI(Y;M)=3.315
# - Layer 3 upper: MI(X;M)=9.807, MI(Y;M)=3.095 | lower: MI(X;M)=6.047, MI(Y;M)=2.593 | bin: MI(X;M)=12.540, MI(Y;M)=3.303
# - Layer 4 upper: MI(X;M)=2.027, MI(Y;M)=1.524 | lower: MI(X;M)=0.631, MI(Y;M)=0.491 | bin: MI(X;M)=1.947, MI(Y;M)=1.309
# Doing rawdata/tanh_1024-20-20-20/epoch00000008
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.035, MI(Y;M)=3.290 | lower: MI(X;M)=7.695, MI(Y;M)=2.785 | bin: MI(X;M)=13.135, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.712, MI(Y;M)=3.200 | lower: MI(X;M)=6.537, MI(Y;M)=2.672 | bin: MI(X;M)=12.800, MI(Y;M)=3.316
# - Layer 3 upper: MI(X;M)=9.866, MI(Y;M)=3.120 | lower: MI(X;M)=6.147, MI(Y;M)=2.637 | bin: MI(X;M)=12.493, MI(Y;M)=3.304
# - Layer 4 upper: MI(X;M)=2.209, MI(Y;M)=1.665 | lower: MI(X;M)=0.706, MI(Y;M)=0.552 | bin: MI(X;M)=2.246, MI(Y;M)=1.502
# Doing rawdata/tanh_1024-20-20-20/epoch00000009
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.052, MI(Y;M)=3.293 | lower: MI(X;M)=7.779, MI(Y;M)=2.817 | bin: MI(X;M)=13.128, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.746, MI(Y;M)=3.212 | lower: MI(X;M)=6.615, MI(Y;M)=2.708 | bin: MI(X;M)=12.786, MI(Y;M)=3.315
# - Layer 3 upper: MI(X;M)=9.916, MI(Y;M)=3.140 | lower: MI(X;M)=6.230, MI(Y;M)=2.675 | bin: MI(X;M)=12.480, MI(Y;M)=3.302
# - Layer 4 upper: MI(X;M)=2.369, MI(Y;M)=1.791 | lower: MI(X;M)=0.775, MI(Y;M)=0.610 | bin: MI(X;M)=2.474, MI(Y;M)=1.671
# Doing rawdata/tanh_1024-20-20-20/epoch00000010
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.068, MI(Y;M)=3.296 | lower: MI(X;M)=7.853, MI(Y;M)=2.844 | bin: MI(X;M)=13.131, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.777, MI(Y;M)=3.221 | lower: MI(X;M)=6.684, MI(Y;M)=2.739 | bin: MI(X;M)=12.795, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=9.958, MI(Y;M)=3.156 | lower: MI(X;M)=6.303, MI(Y;M)=2.709 | bin: MI(X;M)=12.455, MI(Y;M)=3.303
# - Layer 4 upper: MI(X;M)=2.513, MI(Y;M)=1.904 | lower: MI(X;M)=0.842, MI(Y;M)=0.666 | bin: MI(X;M)=2.683, MI(Y;M)=1.814
# Doing rawdata/tanh_1024-20-20-20/epoch00000011
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.085, MI(Y;M)=3.299 | lower: MI(X;M)=7.925, MI(Y;M)=2.868 | bin: MI(X;M)=13.122, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.812, MI(Y;M)=3.230 | lower: MI(X;M)=6.755, MI(Y;M)=2.768 | bin: MI(X;M)=12.786, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=10.001, MI(Y;M)=3.171 | lower: MI(X;M)=6.374, MI(Y;M)=2.739 | bin: MI(X;M)=12.440, MI(Y;M)=3.306
# - Layer 4 upper: MI(X;M)=2.647, MI(Y;M)=2.007 | lower: MI(X;M)=0.909, MI(Y;M)=0.723 | bin: MI(X;M)=2.872, MI(Y;M)=1.943
# Doing rawdata/tanh_1024-20-20-20/epoch00000012
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.099, MI(Y;M)=3.300 | lower: MI(X;M)=7.980, MI(Y;M)=2.888 | bin: MI(X;M)=13.121, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.836, MI(Y;M)=3.237 | lower: MI(X;M)=6.807, MI(Y;M)=2.793 | bin: MI(X;M)=12.795, MI(Y;M)=3.316
# - Layer 3 upper: MI(X;M)=10.035, MI(Y;M)=3.183 | lower: MI(X;M)=6.430, MI(Y;M)=2.767 | bin: MI(X;M)=12.435, MI(Y;M)=3.306
# - Layer 4 upper: MI(X;M)=2.759, MI(Y;M)=2.097 | lower: MI(X;M)=0.969, MI(Y;M)=0.774 | bin: MI(X;M)=3.007, MI(Y;M)=2.043
# Doing rawdata/tanh_1024-20-20-20/epoch00000013
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.114, MI(Y;M)=3.302 | lower: MI(X;M)=8.037, MI(Y;M)=2.907 | bin: MI(X;M)=13.118, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.866, MI(Y;M)=3.244 | lower: MI(X;M)=6.864, MI(Y;M)=2.816 | bin: MI(X;M)=12.792, MI(Y;M)=3.316
# - Layer 3 upper: MI(X;M)=10.069, MI(Y;M)=3.193 | lower: MI(X;M)=6.487, MI(Y;M)=2.792 | bin: MI(X;M)=12.421, MI(Y;M)=3.308
# - Layer 4 upper: MI(X;M)=2.864, MI(Y;M)=2.179 | lower: MI(X;M)=1.031, MI(Y;M)=0.827 | bin: MI(X;M)=3.110, MI(Y;M)=2.133
# Doing rawdata/tanh_1024-20-20-20/epoch00000014
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.126, MI(Y;M)=3.303 | lower: MI(X;M)=8.087, MI(Y;M)=2.923 | bin: MI(X;M)=13.117, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.889, MI(Y;M)=3.249 | lower: MI(X;M)=6.913, MI(Y;M)=2.835 | bin: MI(X;M)=12.792, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=10.095, MI(Y;M)=3.202 | lower: MI(X;M)=6.534, MI(Y;M)=2.814 | bin: MI(X;M)=12.415, MI(Y;M)=3.310
# - Layer 4 upper: MI(X;M)=2.956, MI(Y;M)=2.250 | lower: MI(X;M)=1.089, MI(Y;M)=0.876 | bin: MI(X;M)=3.190, MI(Y;M)=2.201
# Doing rawdata/tanh_1024-20-20-20/epoch00000015
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.141, MI(Y;M)=3.305 | lower: MI(X;M)=8.132, MI(Y;M)=2.938 | bin: MI(X;M)=13.111, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.912, MI(Y;M)=3.254 | lower: MI(X;M)=6.955, MI(Y;M)=2.853 | bin: MI(X;M)=12.798, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=10.122, MI(Y;M)=3.209 | lower: MI(X;M)=6.576, MI(Y;M)=2.833 | bin: MI(X;M)=12.416, MI(Y;M)=3.311
# - Layer 4 upper: MI(X;M)=3.034, MI(Y;M)=2.313 | lower: MI(X;M)=1.142, MI(Y;M)=0.923 | bin: MI(X;M)=3.243, MI(Y;M)=2.261
# Doing rawdata/tanh_1024-20-20-20/epoch00000016
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.152, MI(Y;M)=3.306 | lower: MI(X;M)=8.177, MI(Y;M)=2.951 | bin: MI(X;M)=13.121, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.933, MI(Y;M)=3.258 | lower: MI(X;M)=6.997, MI(Y;M)=2.869 | bin: MI(X;M)=12.802, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=10.143, MI(Y;M)=3.216 | lower: MI(X;M)=6.614, MI(Y;M)=2.851 | bin: MI(X;M)=12.400, MI(Y;M)=3.310
# - Layer 4 upper: MI(X;M)=3.105, MI(Y;M)=2.369 | lower: MI(X;M)=1.196, MI(Y;M)=0.970 | bin: MI(X;M)=3.290, MI(Y;M)=2.319
# Doing rawdata/tanh_1024-20-20-20/epoch00000017
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.162, MI(Y;M)=3.307 | lower: MI(X;M)=8.214, MI(Y;M)=2.964 | bin: MI(X;M)=13.122, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.951, MI(Y;M)=3.262 | lower: MI(X;M)=7.035, MI(Y;M)=2.884 | bin: MI(X;M)=12.809, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=10.164, MI(Y;M)=3.222 | lower: MI(X;M)=6.652, MI(Y;M)=2.867 | bin: MI(X;M)=12.394, MI(Y;M)=3.312
# - Layer 4 upper: MI(X;M)=3.167, MI(Y;M)=2.419 | lower: MI(X;M)=1.246, MI(Y;M)=1.015 | bin: MI(X;M)=3.322, MI(Y;M)=2.359
# Doing rawdata/tanh_1024-20-20-20/epoch00000018
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.174, MI(Y;M)=3.308 | lower: MI(X;M)=8.247, MI(Y;M)=2.975 | bin: MI(X;M)=13.121, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.969, MI(Y;M)=3.266 | lower: MI(X;M)=7.066, MI(Y;M)=2.897 | bin: MI(X;M)=12.808, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=10.187, MI(Y;M)=3.228 | lower: MI(X;M)=6.683, MI(Y;M)=2.882 | bin: MI(X;M)=12.401, MI(Y;M)=3.312
# - Layer 4 upper: MI(X;M)=3.219, MI(Y;M)=2.462 | lower: MI(X;M)=1.292, MI(Y;M)=1.055 | bin: MI(X;M)=3.347, MI(Y;M)=2.394
# Doing rawdata/tanh_1024-20-20-20/epoch00000019
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.181, MI(Y;M)=3.308 | lower: MI(X;M)=8.278, MI(Y;M)=2.984 | bin: MI(X;M)=13.122, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.977, MI(Y;M)=3.268 | lower: MI(X;M)=7.089, MI(Y;M)=2.908 | bin: MI(X;M)=12.816, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=10.192, MI(Y;M)=3.232 | lower: MI(X;M)=6.703, MI(Y;M)=2.895 | bin: MI(X;M)=12.377, MI(Y;M)=3.312
# - Layer 4 upper: MI(X;M)=3.266, MI(Y;M)=2.500 | lower: MI(X;M)=1.336, MI(Y;M)=1.095 | bin: MI(X;M)=3.370, MI(Y;M)=2.427
# Doing rawdata/tanh_1024-20-20-20/epoch00000020
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.192, MI(Y;M)=3.309 | lower: MI(X;M)=8.313, MI(Y;M)=2.994 | bin: MI(X;M)=13.119, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=10.994, MI(Y;M)=3.271 | lower: MI(X;M)=7.121, MI(Y;M)=2.920 | bin: MI(X;M)=12.815, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=10.210, MI(Y;M)=3.236 | lower: MI(X;M)=6.733, MI(Y;M)=2.907 | bin: MI(X;M)=12.369, MI(Y;M)=3.312
# - Layer 4 upper: MI(X;M)=3.307, MI(Y;M)=2.534 | lower: MI(X;M)=1.379, MI(Y;M)=1.134 | bin: MI(X;M)=3.387, MI(Y;M)=2.452
# Doing rawdata/tanh_1024-20-20-20/epoch00000025
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.231, MI(Y;M)=3.311 | lower: MI(X;M)=8.434, MI(Y;M)=3.031 | bin: MI(X;M)=13.116, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.042, MI(Y;M)=3.280 | lower: MI(X;M)=7.216, MI(Y;M)=2.963 | bin: MI(X;M)=12.824, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=10.259, MI(Y;M)=3.252 | lower: MI(X;M)=6.824, MI(Y;M)=2.956 | bin: MI(X;M)=12.365, MI(Y;M)=3.311
# - Layer 4 upper: MI(X;M)=3.443, MI(Y;M)=2.655 | lower: MI(X;M)=1.554, MI(Y;M)=1.296 | bin: MI(X;M)=3.432, MI(Y;M)=2.552
# Doing rawdata/tanh_1024-20-20-20/epoch00000030
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.263, MI(Y;M)=3.313 | lower: MI(X;M)=8.529, MI(Y;M)=3.059 | bin: MI(X;M)=13.115, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.075, MI(Y;M)=3.286 | lower: MI(X;M)=7.282, MI(Y;M)=2.994 | bin: MI(X;M)=12.805, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=10.294, MI(Y;M)=3.263 | lower: MI(X;M)=6.891, MI(Y;M)=2.991 | bin: MI(X;M)=12.323, MI(Y;M)=3.313
# - Layer 4 upper: MI(X;M)=3.514, MI(Y;M)=2.727 | lower: MI(X;M)=1.686, MI(Y;M)=1.423 | bin: MI(X;M)=3.446, MI(Y;M)=2.608
# Doing rawdata/tanh_1024-20-20-20/epoch00000035
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.287, MI(Y;M)=3.314 | lower: MI(X;M)=8.599, MI(Y;M)=3.080 | bin: MI(X;M)=13.103, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.095, MI(Y;M)=3.290 | lower: MI(X;M)=7.320, MI(Y;M)=3.016 | bin: MI(X;M)=12.809, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=10.315, MI(Y;M)=3.270 | lower: MI(X;M)=6.933, MI(Y;M)=3.018 | bin: MI(X;M)=12.289, MI(Y;M)=3.314
# - Layer 4 upper: MI(X;M)=3.551, MI(Y;M)=2.774 | lower: MI(X;M)=1.783, MI(Y;M)=1.519 | bin: MI(X;M)=3.451, MI(Y;M)=2.650
# Doing rawdata/tanh_1024-20-20-20/epoch00000040
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.307, MI(Y;M)=3.314 | lower: MI(X;M)=8.658, MI(Y;M)=3.096 | bin: MI(X;M)=13.096, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.109, MI(Y;M)=3.293 | lower: MI(X;M)=7.353, MI(Y;M)=3.035 | bin: MI(X;M)=12.811, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=10.328, MI(Y;M)=3.276 | lower: MI(X;M)=6.969, MI(Y;M)=3.039 | bin: MI(X;M)=12.278, MI(Y;M)=3.313
# - Layer 4 upper: MI(X;M)=3.572, MI(Y;M)=2.807 | lower: MI(X;M)=1.860, MI(Y;M)=1.597 | bin: MI(X;M)=3.451, MI(Y;M)=2.681
# Doing rawdata/tanh_1024-20-20-20/epoch00000045
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.322, MI(Y;M)=3.315 | lower: MI(X;M)=8.702, MI(Y;M)=3.108 | bin: MI(X;M)=13.081, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.111, MI(Y;M)=3.295 | lower: MI(X;M)=7.365, MI(Y;M)=3.048 | bin: MI(X;M)=12.816, MI(Y;M)=3.317
# - Layer 3 upper: MI(X;M)=10.328, MI(Y;M)=3.280 | lower: MI(X;M)=6.984, MI(Y;M)=3.056 | bin: MI(X;M)=12.264, MI(Y;M)=3.315
# - Layer 4 upper: MI(X;M)=3.585, MI(Y;M)=2.833 | lower: MI(X;M)=1.919, MI(Y;M)=1.658 | bin: MI(X;M)=3.450, MI(Y;M)=2.707
# Doing rawdata/tanh_1024-20-20-20/epoch00000050
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.340, MI(Y;M)=3.315 | lower: MI(X;M)=8.754, MI(Y;M)=3.119 | bin: MI(X;M)=13.085, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.127, MI(Y;M)=3.297 | lower: MI(X;M)=7.391, MI(Y;M)=3.061 | bin: MI(X;M)=12.818, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=10.342, MI(Y;M)=3.283 | lower: MI(X;M)=7.014, MI(Y;M)=3.071 | bin: MI(X;M)=12.247, MI(Y;M)=3.315
# - Layer 4 upper: MI(X;M)=3.591, MI(Y;M)=2.853 | lower: MI(X;M)=1.968, MI(Y;M)=1.709 | bin: MI(X;M)=3.448, MI(Y;M)=2.723
# Doing rawdata/tanh_1024-20-20-20/epoch00000055
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.350, MI(Y;M)=3.316 | lower: MI(X;M)=8.790, MI(Y;M)=3.128 | bin: MI(X;M)=13.076, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.134, MI(Y;M)=3.299 | lower: MI(X;M)=7.405, MI(Y;M)=3.071 | bin: MI(X;M)=12.819, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=10.353, MI(Y;M)=3.286 | lower: MI(X;M)=7.035, MI(Y;M)=3.084 | bin: MI(X;M)=12.229, MI(Y;M)=3.316
# - Layer 4 upper: MI(X;M)=3.595, MI(Y;M)=2.871 | lower: MI(X;M)=2.006, MI(Y;M)=1.751 | bin: MI(X;M)=3.446, MI(Y;M)=2.741
# Doing rawdata/tanh_1024-20-20-20/epoch00000060
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.366, MI(Y;M)=3.316 | lower: MI(X;M)=8.829, MI(Y;M)=3.136 | bin: MI(X;M)=13.079, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.144, MI(Y;M)=3.300 | lower: MI(X;M)=7.420, MI(Y;M)=3.080 | bin: MI(X;M)=12.821, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=10.361, MI(Y;M)=3.288 | lower: MI(X;M)=7.051, MI(Y;M)=3.094 | bin: MI(X;M)=12.210, MI(Y;M)=3.315
# - Layer 4 upper: MI(X;M)=3.596, MI(Y;M)=2.886 | lower: MI(X;M)=2.038, MI(Y;M)=1.787 | bin: MI(X;M)=3.444, MI(Y;M)=2.760
# Doing rawdata/tanh_1024-20-20-20/epoch00000065
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.377, MI(Y;M)=3.316 | lower: MI(X;M)=8.860, MI(Y;M)=3.142 | bin: MI(X;M)=13.074, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.153, MI(Y;M)=3.301 | lower: MI(X;M)=7.430, MI(Y;M)=3.087 | bin: MI(X;M)=12.820, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.372, MI(Y;M)=3.290 | lower: MI(X;M)=7.068, MI(Y;M)=3.104 | bin: MI(X;M)=12.211, MI(Y;M)=3.314
# - Layer 4 upper: MI(X;M)=3.597, MI(Y;M)=2.899 | lower: MI(X;M)=2.065, MI(Y;M)=1.817 | bin: MI(X;M)=3.442, MI(Y;M)=2.779
# Doing rawdata/tanh_1024-20-20-20/epoch00000070
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.389, MI(Y;M)=3.316 | lower: MI(X;M)=8.894, MI(Y;M)=3.147 | bin: MI(X;M)=13.077, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.159, MI(Y;M)=3.302 | lower: MI(X;M)=7.440, MI(Y;M)=3.094 | bin: MI(X;M)=12.816, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=10.376, MI(Y;M)=3.292 | lower: MI(X;M)=7.079, MI(Y;M)=3.112 | bin: MI(X;M)=12.206, MI(Y;M)=3.316
# - Layer 4 upper: MI(X;M)=3.596, MI(Y;M)=2.911 | lower: MI(X;M)=2.089, MI(Y;M)=1.845 | bin: MI(X;M)=3.440, MI(Y;M)=2.794
# Doing rawdata/tanh_1024-20-20-20/epoch00000075
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.400, MI(Y;M)=3.316 | lower: MI(X;M)=8.929, MI(Y;M)=3.153 | bin: MI(X;M)=13.070, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.177, MI(Y;M)=3.302 | lower: MI(X;M)=7.465, MI(Y;M)=3.101 | bin: MI(X;M)=12.834, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=10.395, MI(Y;M)=3.294 | lower: MI(X;M)=7.105, MI(Y;M)=3.120 | bin: MI(X;M)=12.194, MI(Y;M)=3.316
# - Layer 4 upper: MI(X;M)=3.595, MI(Y;M)=2.921 | lower: MI(X;M)=2.110, MI(Y;M)=1.869 | bin: MI(X;M)=3.438, MI(Y;M)=2.807
# Doing rawdata/tanh_1024-20-20-20/epoch00000080
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.409, MI(Y;M)=3.316 | lower: MI(X;M)=8.953, MI(Y;M)=3.157 | bin: MI(X;M)=13.079, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.183, MI(Y;M)=3.303 | lower: MI(X;M)=7.470, MI(Y;M)=3.105 | bin: MI(X;M)=12.833, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=10.403, MI(Y;M)=3.295 | lower: MI(X;M)=7.115, MI(Y;M)=3.126 | bin: MI(X;M)=12.196, MI(Y;M)=3.315
# - Layer 4 upper: MI(X;M)=3.594, MI(Y;M)=2.932 | lower: MI(X;M)=2.127, MI(Y;M)=1.890 | bin: MI(X;M)=3.437, MI(Y;M)=2.820
# Doing rawdata/tanh_1024-20-20-20/epoch00000085
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.419, MI(Y;M)=3.316 | lower: MI(X;M)=8.979, MI(Y;M)=3.160 | bin: MI(X;M)=13.083, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.193, MI(Y;M)=3.304 | lower: MI(X;M)=7.481, MI(Y;M)=3.110 | bin: MI(X;M)=12.842, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.413, MI(Y;M)=3.296 | lower: MI(X;M)=7.127, MI(Y;M)=3.132 | bin: MI(X;M)=12.190, MI(Y;M)=3.315
# - Layer 4 upper: MI(X;M)=3.591, MI(Y;M)=2.940 | lower: MI(X;M)=2.143, MI(Y;M)=1.910 | bin: MI(X;M)=3.437, MI(Y;M)=2.825
# Doing rawdata/tanh_1024-20-20-20/epoch00000090
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.431, MI(Y;M)=3.317 | lower: MI(X;M)=9.009, MI(Y;M)=3.164 | bin: MI(X;M)=13.087, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.210, MI(Y;M)=3.304 | lower: MI(X;M)=7.497, MI(Y;M)=3.115 | bin: MI(X;M)=12.844, MI(Y;M)=3.318
# - Layer 3 upper: MI(X;M)=10.432, MI(Y;M)=3.297 | lower: MI(X;M)=7.147, MI(Y;M)=3.137 | bin: MI(X;M)=12.179, MI(Y;M)=3.315
# - Layer 4 upper: MI(X;M)=3.589, MI(Y;M)=2.947 | lower: MI(X;M)=2.158, MI(Y;M)=1.927 | bin: MI(X;M)=3.434, MI(Y;M)=2.843
# Doing rawdata/tanh_1024-20-20-20/epoch00000095
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.435, MI(Y;M)=3.317 | lower: MI(X;M)=9.026, MI(Y;M)=3.166 | bin: MI(X;M)=13.089, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.214, MI(Y;M)=3.305 | lower: MI(X;M)=7.504, MI(Y;M)=3.119 | bin: MI(X;M)=12.835, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.431, MI(Y;M)=3.298 | lower: MI(X;M)=7.151, MI(Y;M)=3.142 | bin: MI(X;M)=12.165, MI(Y;M)=3.316
# - Layer 4 upper: MI(X;M)=3.587, MI(Y;M)=2.954 | lower: MI(X;M)=2.171, MI(Y;M)=1.943 | bin: MI(X;M)=3.432, MI(Y;M)=2.851
# Doing rawdata/tanh_1024-20-20-20/epoch00000100
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.445, MI(Y;M)=3.317 | lower: MI(X;M)=9.046, MI(Y;M)=3.169 | bin: MI(X;M)=13.092, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.227, MI(Y;M)=3.305 | lower: MI(X;M)=7.514, MI(Y;M)=3.122 | bin: MI(X;M)=12.844, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.446, MI(Y;M)=3.298 | lower: MI(X;M)=7.165, MI(Y;M)=3.147 | bin: MI(X;M)=12.176, MI(Y;M)=3.316
# - Layer 4 upper: MI(X;M)=3.584, MI(Y;M)=2.960 | lower: MI(X;M)=2.182, MI(Y;M)=1.957 | bin: MI(X;M)=3.431, MI(Y;M)=2.860
# Doing rawdata/tanh_1024-20-20-20/epoch00000110
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.458, MI(Y;M)=3.317 | lower: MI(X;M)=9.078, MI(Y;M)=3.173 | bin: MI(X;M)=13.102, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.239, MI(Y;M)=3.306 | lower: MI(X;M)=7.525, MI(Y;M)=3.128 | bin: MI(X;M)=12.851, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.458, MI(Y;M)=3.300 | lower: MI(X;M)=7.179, MI(Y;M)=3.154 | bin: MI(X;M)=12.171, MI(Y;M)=3.317
# - Layer 4 upper: MI(X;M)=3.579, MI(Y;M)=2.971 | lower: MI(X;M)=2.203, MI(Y;M)=1.984 | bin: MI(X;M)=3.428, MI(Y;M)=2.876
# Doing rawdata/tanh_1024-20-20-20/epoch00000120
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.467, MI(Y;M)=3.317 | lower: MI(X;M)=9.109, MI(Y;M)=3.176 | bin: MI(X;M)=13.108, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.257, MI(Y;M)=3.306 | lower: MI(X;M)=7.543, MI(Y;M)=3.133 | bin: MI(X;M)=12.849, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.475, MI(Y;M)=3.301 | lower: MI(X;M)=7.199, MI(Y;M)=3.161 | bin: MI(X;M)=12.164, MI(Y;M)=3.317
# - Layer 4 upper: MI(X;M)=3.573, MI(Y;M)=2.980 | lower: MI(X;M)=2.220, MI(Y;M)=2.005 | bin: MI(X;M)=3.426, MI(Y;M)=2.889
# Doing rawdata/tanh_1024-20-20-20/epoch00000130
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.477, MI(Y;M)=3.317 | lower: MI(X;M)=9.130, MI(Y;M)=3.178 | bin: MI(X;M)=13.115, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.266, MI(Y;M)=3.307 | lower: MI(X;M)=7.547, MI(Y;M)=3.138 | bin: MI(X;M)=12.858, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.483, MI(Y;M)=3.302 | lower: MI(X;M)=7.204, MI(Y;M)=3.167 | bin: MI(X;M)=12.163, MI(Y;M)=3.317
# - Layer 4 upper: MI(X;M)=3.567, MI(Y;M)=2.987 | lower: MI(X;M)=2.235, MI(Y;M)=2.025 | bin: MI(X;M)=3.421, MI(Y;M)=2.893
# Doing rawdata/tanh_1024-20-20-20/epoch00000140
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.281, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.482, MI(Y;M)=3.317 | lower: MI(X;M)=9.147, MI(Y;M)=3.180 | bin: MI(X;M)=13.115, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.279, MI(Y;M)=3.307 | lower: MI(X;M)=7.560, MI(Y;M)=3.142 | bin: MI(X;M)=12.865, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.501, MI(Y;M)=3.303 | lower: MI(X;M)=7.223, MI(Y;M)=3.172 | bin: MI(X;M)=12.164, MI(Y;M)=3.317
# - Layer 4 upper: MI(X;M)=3.562, MI(Y;M)=2.993 | lower: MI(X;M)=2.249, MI(Y;M)=2.042 | bin: MI(X;M)=3.420, MI(Y;M)=2.900
# Doing rawdata/tanh_1024-20-20-20/epoch00000150
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.282, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.488, MI(Y;M)=3.317 | lower: MI(X;M)=9.163, MI(Y;M)=3.182 | bin: MI(X;M)=13.122, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.288, MI(Y;M)=3.307 | lower: MI(X;M)=7.567, MI(Y;M)=3.145 | bin: MI(X;M)=12.861, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.507, MI(Y;M)=3.303 | lower: MI(X;M)=7.231, MI(Y;M)=3.176 | bin: MI(X;M)=12.155, MI(Y;M)=3.317
# - Layer 4 upper: MI(X;M)=3.556, MI(Y;M)=2.999 | lower: MI(X;M)=2.261, MI(Y;M)=2.058 | bin: MI(X;M)=3.416, MI(Y;M)=2.912
# Doing rawdata/tanh_1024-20-20-20/epoch00000160
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.282, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.498, MI(Y;M)=3.317 | lower: MI(X;M)=9.180, MI(Y;M)=3.183 | bin: MI(X;M)=13.123, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.303, MI(Y;M)=3.308 | lower: MI(X;M)=7.575, MI(Y;M)=3.148 | bin: MI(X;M)=12.874, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.522, MI(Y;M)=3.304 | lower: MI(X;M)=7.240, MI(Y;M)=3.180 | bin: MI(X;M)=12.161, MI(Y;M)=3.317
# - Layer 4 upper: MI(X;M)=3.551, MI(Y;M)=3.004 | lower: MI(X;M)=2.272, MI(Y;M)=2.072 | bin: MI(X;M)=3.414, MI(Y;M)=2.914
# Doing rawdata/tanh_1024-20-20-20/epoch00000170
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.282, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.498, MI(Y;M)=3.317 | lower: MI(X;M)=9.186, MI(Y;M)=3.184 | bin: MI(X;M)=13.128, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.305, MI(Y;M)=3.308 | lower: MI(X;M)=7.576, MI(Y;M)=3.151 | bin: MI(X;M)=12.863, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.529, MI(Y;M)=3.305 | lower: MI(X;M)=7.248, MI(Y;M)=3.184 | bin: MI(X;M)=12.158, MI(Y;M)=3.318
# - Layer 4 upper: MI(X;M)=3.546, MI(Y;M)=3.008 | lower: MI(X;M)=2.281, MI(Y;M)=2.084 | bin: MI(X;M)=3.411, MI(Y;M)=2.927
# Doing rawdata/tanh_1024-20-20-20/epoch00000180
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.282, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.503, MI(Y;M)=3.317 | lower: MI(X;M)=9.198, MI(Y;M)=3.184 | bin: MI(X;M)=13.129, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.317, MI(Y;M)=3.308 | lower: MI(X;M)=7.584, MI(Y;M)=3.153 | bin: MI(X;M)=12.877, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.534, MI(Y;M)=3.306 | lower: MI(X;M)=7.254, MI(Y;M)=3.187 | bin: MI(X;M)=12.155, MI(Y;M)=3.318
# - Layer 4 upper: MI(X;M)=3.542, MI(Y;M)=3.013 | lower: MI(X;M)=2.290, MI(Y;M)=2.096 | bin: MI(X;M)=3.408, MI(Y;M)=2.928
# Doing rawdata/tanh_1024-20-20-20/epoch00000190
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.282, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.509, MI(Y;M)=3.317 | lower: MI(X;M)=9.203, MI(Y;M)=3.184 | bin: MI(X;M)=13.131, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.326, MI(Y;M)=3.309 | lower: MI(X;M)=7.584, MI(Y;M)=3.155 | bin: MI(X;M)=12.880, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.550, MI(Y;M)=3.306 | lower: MI(X;M)=7.263, MI(Y;M)=3.190 | bin: MI(X;M)=12.181, MI(Y;M)=3.317
# - Layer 4 upper: MI(X;M)=3.537, MI(Y;M)=3.017 | lower: MI(X;M)=2.297, MI(Y;M)=2.106 | bin: MI(X;M)=3.406, MI(Y;M)=2.933
# Doing rawdata/tanh_1024-20-20-20/epoch00000200
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.282, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.509, MI(Y;M)=3.317 | lower: MI(X;M)=9.205, MI(Y;M)=3.184 | bin: MI(X;M)=13.122, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.325, MI(Y;M)=3.309 | lower: MI(X;M)=7.580, MI(Y;M)=3.157 | bin: MI(X;M)=12.882, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.543, MI(Y;M)=3.306 | lower: MI(X;M)=7.258, MI(Y;M)=3.193 | bin: MI(X;M)=12.161, MI(Y;M)=3.318
# - Layer 4 upper: MI(X;M)=3.534, MI(Y;M)=3.021 | lower: MI(X;M)=2.305, MI(Y;M)=2.116 | bin: MI(X;M)=3.403, MI(Y;M)=2.943
# Doing rawdata/tanh_1024-20-20-20/epoch00000300
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.282, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.514, MI(Y;M)=3.317 | lower: MI(X;M)=9.183, MI(Y;M)=3.178 | bin: MI(X;M)=13.126, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.357, MI(Y;M)=3.311 | lower: MI(X;M)=7.554, MI(Y;M)=3.168 | bin: MI(X;M)=12.921, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.587, MI(Y;M)=3.310 | lower: MI(X;M)=7.279, MI(Y;M)=3.213 | bin: MI(X;M)=12.146, MI(Y;M)=3.318
# - Layer 4 upper: MI(X;M)=3.505, MI(Y;M)=3.058 | lower: MI(X;M)=2.355, MI(Y;M)=2.189 | bin: MI(X;M)=3.391, MI(Y;M)=2.976
# Doing rawdata/tanh_1024-20-20-20/epoch00000400
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.282, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.492, MI(Y;M)=3.317 | lower: MI(X;M)=9.067, MI(Y;M)=3.164 | bin: MI(X;M)=13.132, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.345, MI(Y;M)=3.313 | lower: MI(X;M)=7.482, MI(Y;M)=3.176 | bin: MI(X;M)=12.938, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.574, MI(Y;M)=3.312 | lower: MI(X;M)=7.254, MI(Y;M)=3.228 | bin: MI(X;M)=12.100, MI(Y;M)=3.319
# - Layer 4 upper: MI(X;M)=3.484, MI(Y;M)=3.085 | lower: MI(X;M)=2.386, MI(Y;M)=2.238 | bin: MI(X;M)=3.384, MI(Y;M)=3.012
# Doing rawdata/tanh_1024-20-20-20/epoch00000500
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.282, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.465, MI(Y;M)=3.317 | lower: MI(X;M)=8.931, MI(Y;M)=3.150 | bin: MI(X;M)=13.137, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.316, MI(Y;M)=3.313 | lower: MI(X;M)=7.395, MI(Y;M)=3.183 | bin: MI(X;M)=12.940, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.517, MI(Y;M)=3.314 | lower: MI(X;M)=7.191, MI(Y;M)=3.240 | bin: MI(X;M)=12.020, MI(Y;M)=3.319
# - Layer 4 upper: MI(X;M)=3.466, MI(Y;M)=3.104 | lower: MI(X;M)=2.408, MI(Y;M)=2.273 | bin: MI(X;M)=3.375, MI(Y;M)=3.041
# Doing rawdata/tanh_1024-20-20-20/epoch00000600
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.282, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.442, MI(Y;M)=3.317 | lower: MI(X;M)=8.813, MI(Y;M)=3.138 | bin: MI(X;M)=13.149, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.303, MI(Y;M)=3.314 | lower: MI(X;M)=7.332, MI(Y;M)=3.189 | bin: MI(X;M)=12.946, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.447, MI(Y;M)=3.315 | lower: MI(X;M)=7.128, MI(Y;M)=3.248 | bin: MI(X;M)=11.875, MI(Y;M)=3.319
# - Layer 4 upper: MI(X;M)=3.452, MI(Y;M)=3.117 | lower: MI(X;M)=2.424, MI(Y;M)=2.299 | bin: MI(X;M)=3.370, MI(Y;M)=3.060
# Doing rawdata/tanh_1024-20-20-20/epoch00000700
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.282, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.427, MI(Y;M)=3.317 | lower: MI(X;M)=8.723, MI(Y;M)=3.129 | bin: MI(X;M)=13.155, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.280, MI(Y;M)=3.314 | lower: MI(X;M)=7.280, MI(Y;M)=3.195 | bin: MI(X;M)=12.951, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.363, MI(Y;M)=3.315 | lower: MI(X;M)=7.068, MI(Y;M)=3.255 | bin: MI(X;M)=11.742, MI(Y;M)=3.319
# - Layer 4 upper: MI(X;M)=3.441, MI(Y;M)=3.128 | lower: MI(X;M)=2.436, MI(Y;M)=2.319 | bin: MI(X;M)=3.366, MI(Y;M)=3.079
# Doing rawdata/tanh_1024-20-20-20/epoch00000800
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.283, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.424, MI(Y;M)=3.317 | lower: MI(X;M)=8.666, MI(Y;M)=3.124 | bin: MI(X;M)=13.169, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.281, MI(Y;M)=3.315 | lower: MI(X;M)=7.257, MI(Y;M)=3.201 | bin: MI(X;M)=12.946, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.309, MI(Y;M)=3.316 | lower: MI(X;M)=7.039, MI(Y;M)=3.259 | bin: MI(X;M)=11.640, MI(Y;M)=3.319
# - Layer 4 upper: MI(X;M)=3.431, MI(Y;M)=3.132 | lower: MI(X;M)=2.446, MI(Y;M)=2.333 | bin: MI(X;M)=3.361, MI(Y;M)=3.084
# Doing rawdata/tanh_1024-20-20-20/epoch00000900
# - Layer 0 upper: MI(X;M)=13.289, MI(Y;M)=3.321 | lower: MI(X;M)=13.283, MI(Y;M)=3.319 | bin: MI(X;M)=13.288, MI(Y;M)=3.319
# - Layer 1 upper: MI(X;M)=12.426, MI(Y;M)=3.317 | lower: MI(X;M)=8.627, MI(Y;M)=3.121 | bin: MI(X;M)=13.178, MI(Y;M)=3.319
# - Layer 2 upper: MI(X;M)=11.277, MI(Y;M)=3.316 | lower: MI(X;M)=7.236, MI(Y;M)=3.206 | bin: MI(X;M)=12.936, MI(Y;M)=3.319
# - Layer 3 upper: MI(X;M)=10.236, MI(Y;M)=3.317 | lower: MI(X;M)=6.995, MI(Y;M)=3.263 | bin: MI(X;M)=11.533, MI(Y;M)=3.319
# - Layer 4 upper: MI(X;M)=3.425, MI(Y;M)=3.136 | lower: MI(X;M)=2.453, MI(Y;M)=2.343 | bin: MI(X;M)=3.355, MI(Y;M)=3.089

# %% [markdown]
# Plot Infoplane Visualization
# ----

# %%
max_epoch = max( (max(vals.keys()) if len(vals) else 0) for vals in measures.values())
sm = plt.cm.ScalarMappable(cmap='gnuplot', norm=plt.Normalize(vmin=0, vmax=COLORBAR_MAX_EPOCHS))
sm._A = []

fig=plt.figure(figsize=(10,5))
for actndx, (activation, vals) in enumerate(measures.items()):
    epochs = sorted(vals.keys())
    if not len(epochs):
        continue
    plt.subplot(1,2,actndx+1)    
    for epoch in epochs:
        c = sm.to_rgba(epoch)
        xmvals = np.array(vals[epoch]['MI_XM_'+infoplane_measure])[PLOT_LAYERS]
        ymvals = np.array(vals[epoch]['MI_YM_'+infoplane_measure])[PLOT_LAYERS]

        plt.plot(xmvals, ymvals, c=c, alpha=0.1, zorder=1)
        plt.scatter(xmvals, ymvals, s=20, facecolors=[c for _ in PLOT_LAYERS], edgecolor='none', zorder=2)
    
    plt.ylim([0, 3.5])
    plt.xlim([0, 14])
    plt.xlabel('I(X;M)')
    plt.ylabel('I(Y;M)')
    plt.title(activation)
    
cbaxes = fig.add_axes([1.0, 0.125, 0.03, 0.8]) 
plt.colorbar(sm, label='Epoch', cax=cbaxes)
plt.tight_layout()

if DO_SAVE:
    plt.savefig('plots/' + DIR_TEMPLATE % ('infoplane_'+ARCH),bbox_inches='tight')
# Out:
# /Users/andreybrylov/anaconda2/lib/python2.7/site-packages/matplotlib/figure.py:1999: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
